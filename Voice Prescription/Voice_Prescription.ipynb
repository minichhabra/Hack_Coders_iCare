# %%
import cv2
import os
from datetime import date
from PIL import Image
date = date.today().strftime("%d/%m/%Y")

# %%
black = (1,1,1)
white = (255,255,255)

# %%
global Serial_No
Serial_No=0

# %%
global Name, Age, Gender, Symptom, Diagnosis, Advice, bill_amt, med, af_bf, amt, t_med
Name = ""
Age = ""
Gender= ""
Symptom = ""
Diagnosis = ""
Advice = ""
bill_amt="Rs."
med=""
af_bf=""
amt=""
t_med=""

# %%
templete = cv2.imread('PMSHOSPITAL.png' )

# %%
def serial_number():
    global Serial_No
    Serial_No = Serial_No+1
    generate()

def name(x):
    global Name
    Name = x
    generate()

def age(x):
    global Age
    Age = x
    generate()

def gender(x):
    global Gender
    if x=="mail":
        x="male"
    Gender = x
    generate()

def symptoms(x):
    global Symptom
    Symptom = x
    generate()

def diagnosis(x):
    global Diagnosis
    Diagnosis = x
    generate()

def advice(x):
    global Advice
    Advice = x
    generate()
    
def bill(x):
    global bill_amt
    bill_amt =x
    generate()
    
def medicines(x):
    global med
    med=x
    generate()
    
def amount(x):
    global amt
    amt=x
    generate()
    
def af_bf(x):
    global af_bf
    af_bf=x
    generate()
    
def time_med(x):
    global t_med
    t_med=x;
    generate()

# %%
def save():
    global Serial_No
    im_pil = Image.fromarray(cv2.cvtColor(templete,cv2.COLOR_BGR2RGB))
    im_pil.save("prescription_" + str(Serial_No) + ".jpg",resolution = 100)

# %%
pos_x=1074
pos_y=54
pos_y1=588
pos_y2=768
pos_y3=945

# %%
def generate():
    write(str(Name),(471,309))
    write(str(Age),(256,408))
    write(str(Gender),(595,408))
    write(str(Symptom),(383,665))
    write(str(Diagnosis),(361,753))
    write(str(Advice),(301,849))
    write(str(date),(268,509))
    write(str(Serial_No),(623,509))
    write(str(bill_amt),(921,1595))
    write(str(med),(pos_y,pos_x))
    write(str(amt),(pos_y1,pos_x))
    write(str(af_bf),(pos_y2,pos_x))
    write(str(t_med),(pos_y3,pos_x))

# %%
def write(text,origin, color=black,size=1):
    global templete
    cv2.putText(templete, text , origin ,  cv2.FONT_HERSHEY_DUPLEX, size, color , 1, cv2.LINE_AA)

# %%
import speech_recognition as sr
import pyttsx3 
  
# Initialize the recognizer 
r = sr.Recognizer()

# %%
# Function to convert text to speech
def SpeakText(command):
      
    # Initialize the engine
    engine = pyttsx3.init()
    engine.say(command) 
    engine.runAndWait()

# %%
def call():
    templete = cv2.imread('PMSHOSPITAL.png' )
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.5)
            
                engine = pyttsx3.init()
                engine.say("Name") 
                engine.runAndWait()
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                name(MyText)
    
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.5)
            
                SpeakText("Age")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                age(MyText)
    
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.5)
            
                SpeakText("Gender")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                gender(MyText)
    
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.5)
            
                SpeakText("Symptoms")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                symptoms(MyText)
       
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.5)
            
                SpeakText("Diagnosis")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                diagnosis(MyText)
       
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.5)
            
                SpeakText("Advice")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                advice(MyText)
       
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText=""
    while(MyText==""):
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.1)
            
                SpeakText("Billing Amount")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
  
                bill(MyText)
       
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
    MyText="yes"
    while(MyText=="yes"):
        MyText=""
        while(MyText==""):
            try:
                # use the microphone as source for input.
                with sr.Microphone() as source2:
                    # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                    r.adjust_for_ambient_noise(source2, duration=0.1)
            
                    SpeakText("Medicine")
              
                    #listens for the user's input 
                    audio2 = r.listen(source2)
              
                    # Using google to recognize audio
                    MyText = r.recognize_google(audio2)
                    MyText = MyText.lower()
  
                    medicines(MyText)
       
            except sr.RequestError as e:
                print("Could not request results; {0}".format(e))
          
            except sr.UnknownValueError:
                print("unknown error occured")
        MyText=""
        while(MyText==""):
            try:
                # use the microphone as source for input.
                with sr.Microphone() as source2:
                    # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                    r.adjust_for_ambient_noise(source2, duration=0.1)
            
                    SpeakText("Quantity")
              
                    #listens for the user's input 
                    audio2 = r.listen(source2)
              
                    # Using google to recognize audio
                    MyText = r.recognize_google(audio2)
                    MyText = MyText.lower()
  
                    amount(MyText)
       
            except sr.RequestError as e:
                print("Could not request results; {0}".format(e))
          
            except sr.UnknownValueError:
                print("unknown error occured")
        MyText=""
        while(MyText==""):
            try:
                # use the microphone as source for input.
                with sr.Microphone() as source2:
                    # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                    r.adjust_for_ambient_noise(source2, duration=0.1)
            
                    SpeakText("Before After")
              
                    #listens for the user's input 
                    audio2 = r.listen(source2)
              
                    # Using google to recognize audio
                    MyText = r.recognize_google(audio2)
                    MyText = MyText.lower()
  
                    af_bf(MyText)
       
            except sr.RequestError as e:
                print("Could not request results; {0}".format(e))
          
            except sr.UnknownValueError:
                print("unknown error occured")
        MyText=""
        while(MyText==""):
            try:
                # use the microphone as source for input.
                with sr.Microphone() as source2:
                    # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                    r.adjust_for_ambient_noise(source2, duration=0.1)
            
                    SpeakText("Timings")
              
                    #listens for the user's input 
                    audio2 = r.listen(source2)
              
                    # Using google to recognize audio
                    MyText = r.recognize_google(audio2)
                    MyText = MyText.lower()
  
                    time_med(MyText)
       
            except sr.RequestError as e:
                print("Could not request results; {0}".format(e))
          
            except sr.UnknownValueError:
                print("unknown error occured")
        try:
            # use the microphone as source for input.
            with sr.Microphone() as source2:
                # wait for a second to let the recognizer adjust the energy threshold based on the surrounding noise level 
                r.adjust_for_ambient_noise(source2, duration=0.1)
            
                SpeakText("DO you want to add any other medicine?")
              
                #listens for the user's input 
                audio2 = r.listen(source2)
              
                # Using google to recognize audio
                MyText = r.recognize_google(audio2)
                MyText = MyText.lower()
                pos_x=pos_x+65
  
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
          
        except sr.UnknownValueError:
            print("unknown error occured")
       
    
    save()

# %%
from flask import Flask, render_template, Response, request, redirect, url_for
app = Flask(__name__)

@app.route("/")
def index():
    return render_template('json.html')

#background process happening without any refreshing
@app.route("/static/json.html", methods=['GET','POST'])
def background_process_test():
    templete = cv2.imread('PMSHOSPITAL.png' )
    call()
    return render_template('json.html')    
    
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/Apr/2021 12:11:59] "GET / HTTP/1.1" 200 -
